# %% [markdown]
# # Sample Notebook
#
# This is a test notebook for ipynvim.

# %%
print('Hello, ipynvim!')
# Out:
# Hello, ipynvim!

# %%
import numpy as np
x = np.array([1, 2, 3])
x.sum() + 36
# Out:
# 42

# %% [markdown]
# ## Conclusion
#
# End of notebook.
